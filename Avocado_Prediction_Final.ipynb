# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\HP\Downloads\Avocado Project\avocado.csv\avocado.csv")

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (18249, 14)

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
import seaborn as sns
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.drop(columns = ['Unnamed: 0'], axis =1, inplace = True)

# %%
df.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
df.shape
# Out:
# (18249, 13)

# %%
df.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags          year
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507   2016.147899
# ...

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### Data Visualization :

# %%
# Since the type is a nominal data we will plot the countplot to check its count:

# %%
ab = sns.countplot(x = "type", data = df)
print(df["type"].value_counts())
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %% [markdown]
# #### * The number of conventional and organic avocado are almost same

# %%
# Year wise count of avocado:

cd = sns.countplot(x = "year", data = df)
print(df["year"].value_counts())
# Out:
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: year, dtype: int64

# %% [markdown]
# #### * The volume of avocado produced in 2015, 2016 & 2017 is almost same but there was a sharp decrease in production in 2018

# %%
import matplotlib.pyplot as plt

#showing average price rate with respect to region

plt.figure(figsize=(20,12))
sns.barplot(x = df["region"], y =df["AveragePrice"])
plt.xticks(rotation=90)
plt.show()

import warnings
warnings.filterwarnings('ignore')

# %%
# Average price of avocado with respect to the year

plt.figure(figsize=(8,6))
sns.stripplot(x='year',y='AveragePrice',data=df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='AveragePrice'>

# %%
# Changing the date column into seperate columns of Month & Date

df["Date"] = pd.to_datetime(df["Date"])

df["day"]= df["Date"].dt.day

df["Month"]= df["Date"].dt.month

# %%
# Checking the price change w.r.t changinging months :

byDate=df.groupby('Date').mean()

plt.figure(figsize=(15,8))
byDate['AveragePrice'].plot()
plt.title('Average Price vs Time')
# Out:
# Text(0.5, 1.0, 'Average Price vs Time')

# %% [markdown]
# #### * We observe that every year there is a decrease in prices during winters i.e from January, also we see that the prices are increasing from July - August month each year.  Also we observe that the prices increased sharply in September 2017.

# %%
# Plotting the variety and types of bags with time :

xyz = ['4046', '4225', '4770', 'Small Bags', 'Large Bags', 'XLarge Bags'] 

plt.figure(figsize=(30,25))
plotnumber = 1
for i in xyz:
    if plotnumber<=6:
        ax=plt.subplot(3,2,plotnumber)
        sns.lineplot(y=df[i],x=df["Date"],color="red")
        plt.xlabel("Date")
        plt.ylabel(i)
        plt.xticks(rotation = 90)
    plotnumber+=1
plt.show()

# %%
byDate=df.groupby('Date').mean()

plt.figure(figsize=(15,8))
byDate['Total Volume'].plot()
plt.title('Total Volume vs Time')
# Out:
# Text(0.5, 1.0, 'Total Volume vs Time')

# %% [markdown]
# #### * Here again we observe that the volume of avocado decreses around January and increases around July month :

# %%
# Total Volume vs Average Price :

plt.figure(figsize=(15,8))
sns.lineplot(df["AveragePrice"],df["Total Volume"])
plt.xticks()
plt.show()

# %% [markdown]
# #### * From the above we observe as the total volume of the Avocado is more the average price of the Avocado is less

# %%
sns.relplot(x='AveragePrice', y = 'Total Volume', data =df)

# %% [markdown]
# #### * We see that the volume and average prices are linearly dependent on each other

# %%
plt.figure(figsize=(8,6))
sns.stripplot(x='type',y='AveragePrice',data=df)
# Out:
# <AxesSubplot:xlabel='type', ylabel='AveragePrice'>

# %% [markdown]
# #### * We can clearly observe that the average price of Organic is more than the Conventional type of avocado.

# %%
# Plotting the total volume produced by different regions.

plt.figure(figsize=(20,12))
sns.barplot(x = df["region"], y =df["Total Volume"])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.stripplot(x='type',y='Total Volume',data=df)
# Out:
# <AxesSubplot:xlabel='type', ylabel='Total Volume'>

# %% [markdown]
# #### * We observe that the volume of conventional Avocado is more than the Organic type of avocado.

# %%
# Encoding the object datatype using LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder
la=LabelEncoder()

# %%
for i in df.columns:
    if df[i].dtypes == "object":
        df[i] = la.fit_transform(df[i].values.reshape(-1,1))

# %%
df.dtypes
# Out:
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type              int32
# year              int64
# region            int32
# day               int64
# Month             int64
# dtype: object

# %% [markdown]
# ### Multivariate Analysis :

# %%
# Checking the correlation :

# %%
df.corr()
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.192752 -0.208317 -0.172928 -0.179446
# Total Volume     -0.192752      1.000000  0.977863  0.974181  0.872202
# 4046             -0.208317      0.977863  1.000000  0.926110  0.833389
# 4225             -0.172928      0.974181  0.926110  1.000000  0.887855
# 4770             -0.179446      0.872202  0.833389  0.887855  1.000000
# Total Bags       -0.177088      0.963047  0.920057  0.905787  0.792314
# Small Bags       -0.174730      0.967238  0.925280  0.916031  0.802733
# Large Bags       -0.172940      0.880640  0.838645  0.810015  0.698471
# XLarge Bags      -0.117592      0.747157  0.699377  0.688809  0.679861
# type              0.615845     -0.232434 -0.225819 -0.232289 -0.210027
# year              0.093197      0.017193  0.003353 -0.009559 -0.036531
# region           -0.011716      0.174176  0.192073  0.145726  0.095252
# ...

# %%
df_corr = df.corr().abs()
plt.figure(figsize = (18,11))
sns.heatmap(df_corr, annot = True, annot_kws = {'size' :11})
plt.show()

# %%
corr_matrix = df.corr()
corr_matrix["AveragePrice"].sort_values(ascending = False)
# Out:
# AveragePrice    1.000000
# type            0.615845
# Month           0.162409
# year            0.093197
# day             0.027386
# region         -0.011716
# XLarge Bags    -0.117592
# 4225           -0.172928
# Large Bags     -0.172940
# Small Bags     -0.174730
# Total Bags     -0.177088
# 4770           -0.179446
# Total Volume   -0.192752
# 4046           -0.208317
# Name: AveragePrice, dtype: float64

# %% [markdown]
# #### * We observe that the type column shows good positive correlation with the average price whereas other columns show weak correlation with the average price (target) column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  datetime64[ns]
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   4046          18249 non-null  float64
#  4   4225          18249 non-null  float64
#  5   4770          18249 non-null  float64
#  6   Total Bags    18249 non-null  float64
#  7   Small Bags    18249 non-null  float64
#  8   Large Bags    18249 non-null  float64
#  9   XLarge Bags   18249 non-null  float64
#  10  type          18249 non-null  int32
#  11  year          18249 non-null  int64
#  12  region        18249 non-null  int32
#  13  day           18249 non-null  int64
#  14  Month         18249 non-null  int64
# dtypes: datetime64[ns](1), float64(9), int32(2), int64(3)
# memory usage: 1.9 MB

# %%
# Ploting the data distribution of the continuous column:

continuous = df[["Total Volume", "4046", "4225", "4770", "Total Bags", "Small Bags", "Large Bags", "XLarge Bags"]]

# %%
#using distribution plot for checking the skewness:

plt.figure(figsize=(15,30))
plotnumber=1
for i in continuous:
    if plotnumber<=9:
        ax=plt.subplot(3,3,plotnumber)
        sns.distplot(continuous[i])
        plt.xlabel(i,fontsize=15)
        plotnumber+=1
plt.show()

# %%
# From the above we see a lot of skewness in almost all the columns, we will deal with the skewness in further steps.

# %%
df.skew()
# Out:
# AveragePrice     0.580303
# Total Volume     9.007687
# 4046             8.648220
# 4225             8.942466
# 4770            10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# type             0.000329
# year             0.215339
# region           0.000030
# day              0.014310
# Month            0.106617
# dtype: float64

# %%
continuous.skew()      # skewness is to be checked only in continuous columns :
# Out:
# Total Volume     9.007687
# 4046             8.648220
# 4225             8.942466
# 4770            10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# dtype: float64

# %% [markdown]
# #### * We observe that there is a large skewness present in the columns and we need to remove the skewness before model building

# %%
#for skewness removal
from sklearn.preprocessing import PowerTransformer
scale=PowerTransformer()

# %%
continuous1 = ['Total Volume', '4046', '4225',
       '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags']

# %%
df[continuous1]=scale.fit_transform(df[continuous1].values)
df[continuous1]
# Out:
#        Total Volume      4046      4225      4770  Total Bags  Small Bags  \
# 0         -0.086605 -0.658619  0.307313 -0.247250   -0.524004   -0.340627
# 1         -0.155746 -0.776870  0.231647 -0.201041   -0.485890   -0.306425
# 2          0.179327 -0.731947  0.579503 -0.007072   -0.552018   -0.366303
# 3          0.003876 -0.634200  0.415100 -0.148322   -0.695449   -0.496853
# 4         -0.187640 -0.685293  0.224806 -0.137918   -0.669157   -0.477201
# ...             ...       ...       ...       ...         ...         ...
# 18244     -0.674587 -0.467366 -0.919470 -1.238310   -0.334466   -0.178839
# 18245     -0.767550 -0.619883 -0.665372 -1.238310   -0.496897   -0.325977
# 18246     -0.771505 -0.619831 -0.772496  0.401546   -0.490952   -0.308728
# 18247     -0.698077 -0.550282 -0.710543  0.401246   -0.424252   -0.248932
# 18248     -0.663809 -0.367908 -0.785173  0.122919   -0.384961   -0.212590
#
#        Large Bags  XLarge Bags
# 0       -0.773351    -0.699849
# ...

# %%
df.skew()
# Out:
# AveragePrice    0.580303
# Total Volume    0.011171
# 4046           -0.022679
# 4225           -0.017740
# 4770            0.032184
# Total Bags     -0.001626
# Small Bags      0.007058
# Large Bags     -0.073809
# XLarge Bags     0.793520
# type            0.000329
# year            0.215339
# region          0.000030
# day             0.014310
# Month           0.106617
# dtype: float64

# %%
# We see that the skewness is removed to the large extent as expected :

# %%
df
# Out:
#             Date  AveragePrice  Total Volume      4046      4225      4770  \
# 0     2015-12-27          1.33     -0.086605 -0.658619  0.307313 -0.247250
# 1     2015-12-20          1.35     -0.155746 -0.776870  0.231647 -0.201041
# 2     2015-12-13          0.93      0.179327 -0.731947  0.579503 -0.007072
# 3     2015-12-06          1.08      0.003876 -0.634200  0.415100 -0.148322
# 4     2015-11-29          1.28     -0.187640 -0.685293  0.224806 -0.137918
# ...          ...           ...           ...       ...       ...       ...
# 18244 2018-02-04          1.63     -0.674587 -0.467366 -0.919470 -1.238310
# 18245 2018-01-28          1.71     -0.767550 -0.619883 -0.665372 -1.238310
# 18246 2018-01-21          1.87     -0.771505 -0.619831 -0.772496  0.401546
# 18247 2018-01-14          1.93     -0.698077 -0.550282 -0.710543  0.401246
# 18248 2018-01-07          1.62     -0.663809 -0.367908 -0.785173  0.122919
#
# ...

# %%
# Now we will check the outliers present in our dataset:

# %%
df.drop(columns = ['Date'], axis = 1, inplace = True)

# %%
#using box plot for outliers:

plt.figure(figsize=(15,30))
plotnumber=1
for i in df:
    if plotnumber<=18:
        ax=plt.subplot(6,3,plotnumber)
        sns.boxplot(df[i])
        plt.xlabel(i,fontsize=15)
        plotnumber+=1
plt.show()

# %%
# We observe that the outliers are present in some of the columns and we need to get rid of the outliers.

# %%
from scipy.stats import zscore

# using z score for outliers removal: 

zscr=zscore(df[['Total Volume', '4046', '4225', '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags']])
abs_score=np.abs(zscr)

# %%
filter = (abs_score<3).all (axis=1)

# %%
df1 = df[filter]

# %%
# Calculating the data loss after the outliers removal using z-score:

print(" Data loss is : ",((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
#  Data loss is :  0.5370157268891446

# %%
# We see that not much data is removed from the dataset when we are removing the outliers :

# %%
df1.shape
# Out:
# (18151, 14)

# %%
# Splitting the dataset into features(x) and target columns(y) :

x = df1.drop(columns = ['AveragePrice'], axis =1)
y = df1["AveragePrice"]

# %% [markdown]
# ## Model Building :

# %%
from sklearn.model_selection import train_test_split,GridSearchCV,cross_val_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression,Ridge
from sklearn.ensemble import GradientBoostingRegressor, BaggingRegressor
from xgboost import XGBRegressor

# %%
# scaling the datset:

sc = StandardScaler()
x_scaled = sc.fit_transform(x)

# %% [markdown]
# ## Training the model

# %% [markdown]
# ### Finding the best random state :

# %%
lr = LinearRegression()

for i in range(0,100):
    x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size =0.20, random_state =i)
    lr.fit(x_train, y_train)
    pred_train = lr.predict(x_train)
    pred_test = lr.predict(x_test)
    print(f"At random state {i}, the training accuracy is : {r2_score(y_train, pred_train)}" )
    print(f"At random state {i}, the testing accuracy is : {r2_score(y_test, pred_test)}" )
    print('\n')
# Out:
# At random state 0, the training accuracy is : 0.5668173190082532
# At random state 0, the testing accuracy is : 0.562063013769688
#
#
# At random state 1, the training accuracy is : 0.5636144778678549
# At random state 1, the testing accuracy is : 0.5752070150573507
#
#
# At random state 2, the training accuracy is : 0.5687580026972603
# At random state 2, the testing accuracy is : 0.554521405644717
#
#
# At random state 3, the training accuracy is : 0.5665501783526522
# At random state 3, the testing accuracy is : 0.563024078670272
#
#
# At random state 4, the training accuracy is : 0.5678933530529358
# At random state 4, the testing accuracy is : 0.558376767803562
#
#
# At random state 5, the training accuracy is : 0.5671356472127647
# At random state 5, the testing accuracy is : 0.5610019477020226
#
#
# At random state 6, the training accuracy is : 0.5671677999964437
# At random state 6, the testing accuracy is : 0.560690252070154
#
#
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size = 0.20, random_state = 51)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.model_selection import cross_val_score

# %%
x_train, cv_x, y_train, cv_y = train_test_split(x_train, y_train, test_size = 0.20)

# %%
# checking the shape of x_train, x_test, y_train, y_test, cv_x, cv_y

x_train.shape, x_test.shape, y_train.shape, y_test.shape, cv_x.shape, cv_y.shape
# Out:
# ((11616, 13), (3631, 13), (11616,), (3631,), (2904, 13), (2904,))

# %%
def fun(instance, x_train, y_train, x_test, y_test,cv_x, cv_y):
    instances = instance.fit(x_train,y_train)
    train_pred = instances.predict(x_train)
    test_pred = instances.predict(x_test)
    print('r2_score', r2_score(y_test, test_pred))
    print('Mean squared error:',mean_squared_error(y_test,test_pred))
    print('Root mean squared error:',np.sqrt(mean_squared_error(y_test, test_pred)))
    print('cross_val_score',cross_val_score(instances,cv_x,cv_y))
    print('cross_val_score Mean',cross_val_score(instances,cv_x,cv_y).mean())

# %% [markdown]
# ### Linear Regression :

# %%
model1 = LinearRegression()
fun(model1, x_train, y_train, x_test, y_test, cv_x, cv_y)
# Out:
# r2_score 0.5681079736836351
# Mean squared error: 0.0694699058101665
# Root mean squared error: 0.26357144346489153
# cross_val_score [0.5543827  0.59001278 0.56109077 0.56365003 0.54247764]
# cross_val_score Mean 0.5623227858613088

# %% [markdown]
# ### XGBoost

# %%
model2 = XGBRegressor()
fun(model2, x_train, y_train, x_test, y_test, cv_x, cv_y)
# Out:
# r2_score 0.8930661118506633
# Mean squared error: 0.017200334076572447
# Root mean squared error: 0.1311500441348475
# cross_val_score [0.7857348  0.80898356 0.80290084 0.81962941 0.7807767 ]
# cross_val_score Mean 0.7996050637064631

# %% [markdown]
# ### SVR

# %%
from sklearn.svm import SVR

model3 = SVR()

fun(model3, x_train,y_train, x_test, y_test, cv_x, cv_y)
# Out:
# r2_score 0.7807447524515622
# Mean squared error: 0.035267243818984974
# Root mean squared error: 0.18779575026870277
# cross_val_score [0.71289218 0.73472387 0.72623838 0.7271902  0.67970455]
# cross_val_score Mean 0.7161498351894552

# %% [markdown]
# ### AdaboostRegressor

# %%
from sklearn.ensemble import AdaBoostRegressor

model4 = AdaBoostRegressor()

fun(model4, x_train, y_train, x_test, y_test, cv_x, cv_y)
# Out:
# r2_score 0.5719580707257099
# Mean squared error: 0.06885061704682864
# Root mean squared error: 0.26239401107271604
# cross_val_score [0.55401907 0.57851721 0.55224356 0.55495854 0.5733691 ]
# cross_val_score Mean 0.5603045234641753

# %% [markdown]
# ### Bagging Regressor

# %%
from sklearn.ensemble import BaggingRegressor

model5 = BaggingRegressor()

fun(model5, x_train, y_train, x_test, y_test, cv_x, cv_y)
# Out:
# r2_score 0.8651998786700384
# Mean squared error: 0.02168262241806665
# Root mean squared error: 0.14725020345679204
# cross_val_score [0.74010099 0.7640784  0.70412292 0.76622463 0.70304771]
# cross_val_score Mean 0.7327755111088583

# %% [markdown]
# #### * Based on above results of the various models, we observe that the XGBoost is giving the best results, hence we choose xgboost as our model and tune the model for better results.

# %% [markdown]
# ### HyperParameter Tunning :

# %%
from sklearn.model_selection import train_test_split,cross_val_score,GridSearchCV,KFold

# %%
k=KFold(n_splits=5,random_state=51,shuffle=True)

# %%
grid_param = {'max_depth':range(4,12,2) ,
              'learning_rate':np.arange(0.1,1,0.1), 
              'n_estimators':[50,100,150,200]}

# %%
xgb = XGBRegressor()

# %%
grid = GridSearchCV(xgb, param_grid = grid_param, cv=k)

# %%
grid.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=51, shuffle=True),
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     gamma=None, gpu_id=None, grow_policy=None,
#                                     importance_type=None,
#                                     interaction_constraints...
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
# ...

# %%
grid.best_params_
# Out:
# {'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 200}

# %%
xgb = XGBRegressor(max_depth=8,learning_rate =0.1 ,n_estimators=200)

# %%
xgb.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.1, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=8, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=200, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %%
y_pred = xgb.predict(x_test)

# %%
print("r-2 score : ",r2_score(y_test,y_pred),"\n","cross validation score :",cross_val_score(xgb,x_scaled,y,cv=k).mean())
# Out:
# r-2 score :  0.9138623590198345
#  cross validation score : 0.9203196591084171

# %% [markdown]
# #### * we see that our r2 score as well as cross validation score has increased considerably after hyperparameter tunning.

# %% [markdown]
# ## Classification - Target - Region

# %%
df1.columns
# Out:
# Index(['AveragePrice', 'Total Volume', '4046', '4225', '4770', 'Total Bags',
#        'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year', 'region',
#        'day', 'Month'],
#       dtype='object')

# %%
df1.shape
# Out:
# (18151, 14)

# %%
# Splitting the dataset into features(x) and target columns(y) :

X = df1.drop(columns = ['region'], axis =1)
Y = df1["region"]

# %%
from sklearn.model_selection import train_test_split,GridSearchCV,cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_auc_score
from sklearn.linear_model import LogisticRegression,Ridge
from sklearn.ensemble import GradientBoostingClassifier, BaggingClassifier, RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %%
# scaling the datset:

sc = StandardScaler()
X_scaled = sc.fit_transform(X)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y, test_size = 0.20, random_state = 51)

# %%
X_train, cv_X, Y_train, cv_Y = train_test_split(X_train, Y_train, test_size = 0.20)

# %%
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape, cv_X.shape, cv_X.shape
# Out:
# ((11616, 13), (3631, 13), (11616,), (3631,), (2904, 13), (2904, 13))

# %%
import lazypredict
from lazypredict.Supervised import LazyClassifier

# %%
clf = LazyClassifier(verbose = 0, ignore_warnings = True)
models, predictions = clf.fit(X_train, X_test, Y_train, Y_test)
models
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 29/29 [02:17<00:00,  4.73s/it]
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# ExtraTreesClassifier               0.92               0.92    None      0.92
# RandomForestClassifier             0.91               0.91    None      0.91
# LGBMClassifier                     0.90               0.90    None      0.90
# XGBClassifier                      0.89               0.89    None      0.89
# BaggingClassifier                  0.87               0.87    None      0.87
# QuadraticDiscriminantAnalysis      0.83               0.83    None      0.83
# DecisionTreeClassifier             0.79               0.79    None      0.79
# SVC                                0.78               0.78    None      0.78
# NuSVC                              0.76               0.76    None      0.76
# ...

# %%
# Based on the above result we will define a function and train a few models which are giving the best result :

# %%
def func(instance, X_train, Y_train, X_test, Y_test, cv_X, cv_Y):
    instances = instance.fit(X_train,Y_train)
    train_pred = instances.predict(X_train)
    test_pred = instances.predict(X_test)
    print('training confucion matrix',confusion_matrix(Y_train,train_pred))
    print('testing confucion matrix',confusion_matrix(Y_test,test_pred))
    print('test ',classification_report(Y_test, test_pred))
    print('training ',classification_report(Y_train, train_pred))
    print('cross_val_score',cross_val_score(instances,cv_X,cv_Y))
    print('cross_val_score Mean',cross_val_score(instances,cv_X,cv_Y).mean())

# %%
model1 = KNeighborsClassifier()
func(model1, X_train,Y_train,X_test,Y_test,cv_X,cv_Y)
# Out:
# training confucion matrix [[205   0   0 ...   0   0   0]
#  [  0 152   0 ...   0   0   2]
#  [  0   0 203 ...   0   0   0]
#  ...
#  [  0   0   0 ... 184   0   0]
#  [  0   0   0 ...   0 190   0]
#  [  0   6   0 ...   0   0 143]]
# testing confucion matrix [[63  0  0 ...  0  0  0]
#  [ 0 31  0 ...  0  0  1]
#  [ 0  0 60 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 45  0  0]
#  [ 0  0  0 ...  1 55  0]
#  [ 0  1  0 ...  0  0 23]]
# test                precision    recall  f1-score   support
#
#            0       0.61      0.90      0.73        70
#            1       0.32      0.44      0.37        71
#            2       0.63      0.83      0.72        72
#            3       0.58      0.81      0.68        57
#            4       0.65      0.67      0.66        63
#            5       0.61      0.62      0.61        69
#            6       0.70      0.85      0.77        55
#            7       0.53      0.71      0.61        69
#            8       0.85      0.82      0.84        78
# ...

# %%
model2 = DecisionTreeClassifier()
func(model2, X_train,Y_train,X_test,Y_test,cv_X,cv_Y)
# Out:
# training confucion matrix [[218   0   0 ...   0   0   0]
#  [  0 215   0 ...   0   0   0]
#  [  0   0 210 ...   0   0   0]
#  ...
#  [  0   0   0 ... 184   0   0]
#  [  0   0   0 ...   0 199   0]
#  [  0   0   0 ...   0   0 219]]
# testing confucion matrix [[50  0  0 ...  0  0  0]
#  [ 0 49  0 ...  0  0  0]
#  [ 0  0 67 ...  0  0  1]
#  ...
#  [ 0  0  0 ... 44  0  0]
#  [ 0  1  0 ...  0 64  0]
#  [ 0  0  1 ...  0  0 40]]
# test                precision    recall  f1-score   support
#
#            0       0.70      0.71      0.71        70
#            1       0.67      0.69      0.68        71
#            2       0.87      0.93      0.90        72
#            3       0.78      0.89      0.84        57
#            4       0.77      0.89      0.82        63
#            5       0.72      0.71      0.72        69
#            6       0.91      0.96      0.94        55
#            7       0.77      0.74      0.76        69
#            8       0.94      0.97      0.96        78
# ...

# %%
model3 = GradientBoostingClassifier()
func(model3, X_train,Y_train,X_test,Y_test,cv_X,cv_Y)
# Out:
# training confucion matrix [[216   0   0 ...   0   0   0]
#  [  0 208   0 ...   0   0   0]
#  [  0   0 210 ...   0   0   0]
#  ...
#  [  0   0   0 ... 184   0   0]
#  [  0   0   0 ...   0 199   0]
#  [  0   1   0 ...   0   0 216]]
# testing confucion matrix [[57  0  0 ...  0  0  0]
#  [ 0 58  0 ...  0  0  0]
#  [ 0  0 65 ...  0  0  1]
#  ...
#  [ 0  0  0 ... 45  0  0]
#  [ 0  0  0 ...  1 67  0]
#  [ 0  1  1 ...  0  0 42]]
# test                precision    recall  f1-score   support
#
#            0       0.83      0.81      0.82        70
#            1       0.83      0.82      0.82        71
#            2       0.90      0.90      0.90        72
#            3       0.87      0.93      0.90        57
#            4       0.83      0.86      0.84        63
#            5       0.76      0.83      0.79        69
#            6       0.94      0.89      0.92        55
#            7       0.82      0.87      0.85        69
#            8       0.97      0.92      0.95        78
# ...

# %%
model4 = BaggingClassifier()
func(model4, X_train,Y_train,X_test,Y_test,cv_X,cv_Y)
# Out:
# training confucion matrix [[216   0   0 ...   0   0   0]
#  [  0 213   0 ...   0   0   0]
#  [  0   0 210 ...   0   0   0]
#  ...
#  [  0   0   0 ... 184   0   0]
#  [  0   0   0 ...   0 199   0]
#  [  0   0   1 ...   0   0 216]]
# testing confucion matrix [[58  0  0 ...  0  0  0]
#  [ 0 63  0 ...  0  0  0]
#  [ 0  0 69 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 45  0  0]
#  [ 0  0  0 ...  1 73  0]
#  [ 0  0  1 ...  0  0 45]]
# test                precision    recall  f1-score   support
#
#            0       0.79      0.83      0.81        70
#            1       0.81      0.89      0.85        71
#            2       0.92      0.96      0.94        72
#            3       0.83      0.84      0.83        57
#            4       0.85      0.90      0.88        63
#            5       0.85      0.80      0.82        69
#            6       0.93      0.96      0.95        55
#            7       0.85      0.77      0.81        69
#            8       0.94      0.96      0.95        78
# ...

# %%
model5 = RandomForestClassifier()
func(model5, X_train,Y_train,X_test,Y_test,cv_X,cv_Y)
# Out:
# training confucion matrix [[218   0   0 ...   0   0   0]
#  [  0 215   0 ...   0   0   0]
#  [  0   0 210 ...   0   0   0]
#  ...
#  [  0   0   0 ... 184   0   0]
#  [  0   0   0 ...   0 199   0]
#  [  0   0   0 ...   0   0 219]]
# testing confucion matrix [[65  0  0 ...  0  0  0]
#  [ 0 65  0 ...  0  0  0]
#  [ 0  0 70 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 45  0  0]
#  [ 0  0  0 ...  1 73  0]
#  [ 0  0  1 ...  0  0 48]]
# test                precision    recall  f1-score   support
#
#            0       0.87      0.93      0.90        70
#            1       0.88      0.92      0.90        71
#            2       0.95      0.97      0.96        72
#            3       0.89      0.95      0.92        57
#            4       0.94      0.97      0.95        63
#            5       0.93      0.81      0.87        69
#            6       0.96      0.98      0.97        55
#            7       0.95      0.86      0.90        69
#            8       0.96      0.97      0.97        78
# ...

# %%
model6 = SVC()
func(model6, X_train,Y_train,X_test,Y_test,cv_X,cv_Y)
# Out:
# training confucion matrix [[206   0   0 ...   0   0   0]
#  [  0 135   0 ...   0   0   1]
#  [  0   0 209 ...   0   0   0]
#  ...
#  [  0   0   0 ... 184   0   0]
#  [  0   0   0 ...   0 193   0]
#  [  0   4   0 ...   0   0 154]]
# testing confucion matrix [[67  0  0 ...  0  0  0]
#  [ 0 44  0 ...  0  0  0]
#  [ 0  0 71 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 45  0  0]
#  [ 0  0  0 ...  0 68  0]
#  [ 0  1  1 ...  0  0 34]]
# test                precision    recall  f1-score   support
#
#            0       0.74      0.96      0.83        70
#            1       0.54      0.62      0.58        71
#            2       0.87      0.99      0.92        72
#            3       0.84      0.75      0.80        57
#            4       0.88      0.79      0.83        63
#            5       0.79      0.71      0.75        69
#            6       0.93      0.93      0.93        55
#            7       0.78      0.68      0.73        69
#            8       0.99      0.91      0.95        78
# ...

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
model7 = ExtraTreesClassifier()
func(model7, X_train,Y_train,X_test,Y_test,cv_X,cv_Y)
# Out:
# training confucion matrix [[218   0   0 ...   0   0   0]
#  [  0 215   0 ...   0   0   0]
#  [  0   0 210 ...   0   0   0]
#  ...
#  [  0   0   0 ... 184   0   0]
#  [  0   0   0 ...   0 199   0]
#  [  0   0   0 ...   0   0 219]]
# testing confucion matrix [[68  0  0 ...  0  0  0]
#  [ 0 67  0 ...  0  0  0]
#  [ 0  0 72 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 45  0  0]
#  [ 0  0  0 ...  1 72  0]
#  [ 0  0  0 ...  0  0 50]]
# test                precision    recall  f1-score   support
#
#            0       0.85      0.97      0.91        70
#            1       0.88      0.94      0.91        71
#            2       0.99      1.00      0.99        72
#            3       0.92      0.96      0.94        57
#            4       0.97      0.95      0.96        63
#            5       0.93      0.81      0.87        69
#            6       1.00      0.98      0.99        55
#            7       0.97      0.86      0.91        69
#            8       0.97      1.00      0.99        78
# ...

# %% [markdown]
# ####  * Based on the above results we choose ExtraTreeClassifier as our model

# %% [markdown]
# ## Hyperparameter tunning of the best model - ExtraTreeClassifier :

# %%
clf = ExtraTreesClassifier()

# %%
params = {'max_depth' : (4,8,12,16), 'min_samples_split':(4,8,12,16),'criterion':['gini', 'entropy'], 
          'n_estimators' : [5,25,100,125], 'max_features':['sqrt', 'log2']}

# %%
grd = GridSearchCV(clf, param_grid = params)

grd.fit(X_train, Y_train)
# Out:
# GridSearchCV(estimator=ExtraTreesClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': (4, 8, 12, 16),
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_split': (4, 8, 12, 16),
#                          'n_estimators': [5, 25, 100, 125]})

# %%
print("Best Parameters =" ,grd.best_params_)
# Out:
# Best Parameters = {'criterion': 'entropy', 'max_depth': 16, 'max_features': 'log2', 'min_samples_split': 4, 'n_estimators': 125}

# %%
xt_clf = ExtraTreesClassifier(max_depth = 18, min_samples_split = 3, 
                              criterion = 'gini', n_estimators = 135, max_features = 'sqrt')

# %%
model8 = xt_clf
func(model8, X_train,Y_train,X_test,Y_test,cv_X,cv_Y)
# Out:
# training confucion matrix [[218   0   0 ...   0   0   0]
#  [  0 215   0 ...   0   0   0]
#  [  0   0 210 ...   0   0   0]
#  ...
#  [  0   0   0 ... 184   0   0]
#  [  0   0   0 ...   0 199   0]
#  [  0   0   0 ...   0   0 219]]
# testing confucion matrix [[68  0  0 ...  0  0  0]
#  [ 0 68  0 ...  0  0  0]
#  [ 0  0 72 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 45  0  0]
#  [ 0  0  0 ...  1 73  0]
#  [ 0  0  0 ...  0  0 49]]
# test                precision    recall  f1-score   support
#
#            0       0.83      0.97      0.89        70
#            1       0.87      0.96      0.91        71
#            2       0.99      1.00      0.99        72
#            3       0.95      0.95      0.95        57
#            4       0.95      0.97      0.96        63
#            5       0.97      0.86      0.91        69
#            6       0.96      0.98      0.97        55
#            7       0.97      0.86      0.91        69
#            8       0.99      1.00      0.99        78
# ...

# %% [markdown]
# #### *  We observe that our cross_val_score has increased after hyperparameter tunning of the model ExtraTreeClassifier:

# %% [markdown]
# #### Saving the model

# %%
# Saving the model :

import joblib #importing the job
  
# Save the model as a pickle in a file 
joblib.dump(xt_clf,'avocado1.pkl')
# Out:
# ['avocado1.pkl']

# %%
#saving the predicted as csv

joblib.dump(xt_clf,'avocado1.csv')
# Out:
# ['avocado1.csv']

# %%
#lets call the model and predict it
P=joblib.load('avocado1.csv')
P.predict(X_test)
# Out:
# array([22, 21, 41, ..., 39, 22, 50])
