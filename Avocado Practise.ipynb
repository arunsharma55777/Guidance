# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\HP\Downloads\avocado.csv\avocado.csv")

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany
# 4  2015  Albany

# %%
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0       48.16     8696.87     8603.62       93.25          0.0  conventional
# 1       58.33     9505.56     9408.07       97.49          0.0  conventional
# 2      130.50     8145.35     8042.21      103.14          0.0  conventional
# 3       72.58     5811.16     5677.40      133.76          0.0  conventional
# 4       75.78     6183.95     5986.26      197.69          0.0  conventional
# ...       ...         ...         ...         ...          ...           ...
# 18244    0.00    13498.67    13066.82      431.85          0.0       organic
# 18245    0.00     9264.84     8940.04      324.80          0.0       organic
# 18246  727.94     9394.11     9351.80       42.31          0.0       organic
# 18247  727.01    10969.54    10919.54       50.00          0.0       organic
# 18248  224.53    12014.15    11988.14       26.01          0.0       organic
#
#        year            region
# 0      2015            Albany
# 1      2015            Albany
# 2      2015            Albany
# 3      2015            Albany
# 4      2015            Albany
# ...     ...               ...
# 18244  2018  WestTexNewMexico
# 18245  2018  WestTexNewMexico
# 18246  2018  WestTexNewMexico
# 18247  2018  WestTexNewMexico
# 18248  2018  WestTexNewMexico
#
# [18249 rows x 14 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (18249, 14)

# %%
hij = pd.read_csv(r"https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/avocado.csv")

# %%
hij.head()

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
import seaborn as sns
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.drop(columns = ['Date', 'Unnamed: 0'], axis =1, inplace = True)

# %%
df.columns
# Out:
# Index(['AveragePrice', 'Total Volume', '4046', '4225', '4770', 'Total Bags',
#        'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year', 'region'],
#       dtype='object')

# %%
df.shape
# Out:
# (18249, 12)

# %% [markdown]
# ### Data Visualization :

# %%
# Since the type is a nominal data we will plot the countplot to check its count:

# %%
ab = sns.countplot(x = "type", data = df)
print(df["type"].value_counts())
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %%
cd = sns.countplot(x = "year", data = df)
print(df["year"].value_counts())
# Out:
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: year, dtype: int64

# %%
import matplotlib.pyplot as plt

#showing average price rate with respect to region

plt.figure(figsize=(20,12))
sns.barplot(x = df["region"], y =df["AveragePrice"])
plt.xticks(rotation=90)
plt.show()

import warnings
warnings.filterwarnings('ignore')

# %%
# Checking correlation :

# %%
df.corr()
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.192752 -0.208317 -0.172928 -0.179446
# Total Volume     -0.192752      1.000000  0.977863  0.974181  0.872202
# 4046             -0.208317      0.977863  1.000000  0.926110  0.833389
# 4225             -0.172928      0.974181  0.926110  1.000000  0.887855
# 4770             -0.179446      0.872202  0.833389  0.887855  1.000000
# Total Bags       -0.177088      0.963047  0.920057  0.905787  0.792314
# Small Bags       -0.174730      0.967238  0.925280  0.916031  0.802733
# Large Bags       -0.172940      0.880640  0.838645  0.810015  0.698471
# XLarge Bags      -0.117592      0.747157  0.699377  0.688809  0.679861
# year              0.093197      0.017193  0.003353 -0.009559 -0.036531
#
#               Total Bags  Small Bags  Large Bags  XLarge Bags      year
# AveragePrice   -0.177088   -0.174730   -0.172940    -0.117592  0.093197
# Total Volume    0.963047    0.967238    0.880640     0.747157  0.017193
# 4046            0.920057    0.925280    0.838645     0.699377  0.003353
# 4225            0.905787    0.916031    0.810015     0.688809 -0.009559
# 4770            0.792314    0.802733    0.698471     0.679861 -0.036531
# Total Bags      1.000000    0.994335    0.943009     0.804233  0.071552
# Small Bags      0.994335    1.000000    0.902589     0.806845  0.063915
# Large Bags      0.943009    0.902589    1.000000     0.710858  0.087891
# XLarge Bags     0.804233    0.806845    0.710858     1.000000  0.081033
# year            0.071552    0.063915    0.087891     0.081033  1.000000

# %%
df_corr = df.corr().abs()
plt.figure(figsize = (18,11))
sns.heatmap(df_corr, annot = True, annot_kws = {'size' :11})
plt.show()

# %%
corr_matrix = df.corr()
corr_matrix["AveragePrice"].sort_values(ascending = False)
# Out:
# AveragePrice    1.000000
# year            0.093197
# XLarge Bags    -0.117592
# 4225           -0.172928
# Large Bags     -0.172940
# Small Bags     -0.174730
# Total Bags     -0.177088
# 4770           -0.179446
# Total Volume   -0.192752
# 4046           -0.208317
# Name: AveragePrice, dtype: float64

# %%
# Checking the distribution of the continuous column :

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AveragePrice  18249 non-null  float64
#  1   Total Volume  18249 non-null  float64
#  2   4046          18249 non-null  float64
#  3   4225          18249 non-null  float64
#  4   4770          18249 non-null  float64
#  5   Total Bags    18249 non-null  float64
#  6   Small Bags    18249 non-null  float64
#  7   Large Bags    18249 non-null  float64
#  8   XLarge Bags   18249 non-null  float64
#  9   type          18249 non-null  object
#  10  year          18249 non-null  int64
#  11  region        18249 non-null  object
# dtypes: float64(9), int64(1), object(2)
# memory usage: 1.7+ MB

# %%
df.head()
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5677.40      133.76          0.0  conventional  2015  Albany
# 4     5986.26      197.69          0.0  conventional  2015  Albany

# %%
# Ploting the data distribution of the continuous column:

continuous = df[["Total Volume", "4046", "4225", "4770", "Total Bags", "Small Bags", "Large Bags", "XLarge Bags", "year"]]

# %%
continuous.plot(kind = 'density', subplots = True, layout = (3,3), figsize = (20,20), sharex = True, legend = True, fontsize = 3)
plt.show()

# %%
# From the above we see a lot of skewness in almost all the columns, we will deal with the skewness in further steps.

# %%
# Lets Encode the categorical column using the Label Encoder :

# %%
from sklearn.preprocessing import LabelEncoder
la=LabelEncoder()

# %%
for i in df.columns:
    if df[i].dtypes == "object":
        df[i] = la.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags  type  year  region
# 0         8603.62       93.25          0.0     0  2015       0
# 1         9408.07       97.49          0.0     0  2015       0
# 2         8042.21      103.14          0.0     0  2015       0
# 3         5677.40      133.76          0.0     0  2015       0
# 4         5986.26      197.69          0.0     0  2015       0
# ...           ...         ...          ...   ...   ...     ...
# 18244    13066.82      431.85          0.0     1  2018      53
# 18245     8940.04      324.80          0.0     1  2018      53
# 18246     9351.80       42.31          0.0     1  2018      53
# 18247    10919.54       50.00          0.0     1  2018      53
# 18248    11988.14       26.01          0.0     1  2018      53
#
# [18249 rows x 12 columns]

# %%
df.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags          type  \
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507      0.499918
# std    9.862424e+05  7.461785e+05  2.439660e+05   17692.894652      0.500014
# min    0.000000e+00  0.000000e+00  0.000000e+00       0.000000      0.000000
# 25%    5.088640e+03  2.849420e+03  1.274700e+02       0.000000      0.000000
# 50%    3.974383e+04  2.636282e+04  2.647710e+03       0.000000      0.000000
# 75%    1.107834e+05  8.333767e+04  2.202925e+04     132.500000      1.000000
# max    1.937313e+07  1.338459e+07  5.719097e+06  551693.650000      1.000000
#
#                year        region
# count  18249.000000  18249.000000
# mean    2016.147899     26.495644
# std        0.939938     15.583788
# min     2015.000000      0.000000
# 25%     2015.000000     13.000000
# 50%     2016.000000     26.000000
# 75%     2017.000000     40.000000
# max     2018.000000     53.000000

# %%
df.skew()
# Out:
# AveragePrice     0.580303
# Total Volume     9.007687
# 4046             8.648220
# 4225             8.942466
# 4770            10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# type             0.000329
# year             0.215339
# region           0.000030
# dtype: float64

# %%
continuous.skew()      # skewness is to be checked only in continuous columns :
# Out:
# Total Volume     9.007687
# 4046             8.648220
# 4225             8.942466
# 4770            10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# year             0.215339
# dtype: float64

# %%
# skewness is to be removed from the continuous column only and not the categorical :

# %%
#for skewness removal
from sklearn.preprocessing import PowerTransformer
scale=PowerTransformer(method='yeo-johnson')

# %%
continuous1 = ['Total Volume', '4046', '4225',
       '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags']

# %%
df[continuous1]=scale.fit_transform(df[continuous1].values)
df[continuous1]
# Out:
#        Total Volume      4046      4225      4770  Total Bags  Small Bags  \
# 0         -0.094167 -0.660667  0.300522 -0.246071   -0.528331   -0.344166
# 1         -0.163138 -0.778196  0.224457 -0.199829   -0.490503   -0.310079
# 2          0.171997 -0.733558  0.574906 -0.005791   -0.556123   -0.369750
# 3         -0.003767 -0.636385  0.409041 -0.147079   -0.698279   -0.499743
# 4         -0.194924 -0.687187  0.217585 -0.136671   -0.672238   -0.480184
# ...             ...       ...       ...       ...         ...         ...
# 18244     -0.678228 -0.470376 -0.920043 -1.239006   -0.340035   -0.182823
# 18245     -0.770128 -0.622146 -0.669147 -1.239006   -0.501429   -0.329566
# 18246     -0.774035 -0.622095 -0.775016  0.402587   -0.495528   -0.312374
# 18247     -0.701459 -0.552907 -0.713806  0.402287   -0.429290   -0.252753
# 18248     -0.667567 -0.371308 -0.787535  0.124177   -0.390245   -0.216502
#
#        Large Bags  XLarge Bags
# 0       -0.784189    -0.714438
# 1       -0.774737    -0.714438
# 2       -0.762705    -0.714438
# 3       -0.706377    -0.714438
# 4       -0.619204    -0.714438
# ...           ...          ...
# 18244   -0.435459    -0.714438
# 18245   -0.503931    -0.714438
# 18246   -0.945689    -0.714438
# 18247   -0.912590    -0.714438
# 18248   -1.038880    -0.714438
#
# [18249 rows x 8 columns]

# %%
df.skew()
# Out:
# AveragePrice    0.580303
# Total Volume    0.035774
# 4046           -0.006438
# 4225            0.017923
# 4770            0.029971
# Total Bags      0.030980
# Small Bags      0.030153
# Large Bags      0.039828
# XLarge Bags     0.698965
# type            0.000329
# year            0.215339
# region          0.000030
# dtype: float64

# %%
# We see that the skewness is removed to the large extent as expacted :

# %%
# Now we will check the outliers present in our dataset:

# %%
#using box plot for outliers:

plt.figure(figsize=(15,30))
plotnumber=1
for i in df:
    if plotnumber<=18:
        ax=plt.subplot(6,3,plotnumber)
        sns.boxplot(df[i])
        plt.xlabel(i,fontsize=15)
        plotnumber+=1
plt.show()

# %%
from scipy.stats import zscore
import numpy as np

# using z score for outliers removal: 

zscr=zscore(df[['Total Volume', '4046', '4225', '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags']])
abs_score=np.abs(zscr)

# %%
filter = (abs_score<3).all (axis=1)

# %%
df1 = df[filter]

# %%
# Calculating the data loss after the outliers removal using z-score:

print(" Data loss is : ",((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
#  Data loss is :  0.5534549838347307

# %%
# Splitting the dataset :

x = df1.drop(columns = ['AveragePrice'], axis =1)
y = df1["AveragePrice"]

# %%
from sklearn.model_selection import train_test_split,GridSearchCV,cross_val_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression,Ridge
from sklearn.ensemble import GradientBoostingRegressor, BaggingRegressor
from xgboost import XGBRegressor

# %%
# scaling the datset:

sc = StandardScaler()
x_scaled = sc.fit_transform(x)

# %% [markdown]
# ## Training the model

# %% [markdown]
# ### Finding the best random state :

# %%
lr = LinearRegression()

for i in range(0,100):
    x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size =0.20, random_state =i)
    lr.fit(x_train, y_train)
    pred_train = lr.predict(x_train)
    pred_test = lr.predict(x_test)
    print(f"At random state {i}, the training accuracy is : {r2_score(y_train, pred_train)}" )
    print(f"At random state {i}, the testing accuracy is : {r2_score(y_test, pred_test)}" )
    print('\n')
# Out:
# At random state 0, the training accuracy is : 0.5288103865434683
# At random state 0, the testing accuracy is : 0.5229423525924444
#
#
# At random state 1, the training accuracy is : 0.5267060280871105
# At random state 1, the testing accuracy is : 0.531508458363561
#
#
# At random state 2, the training accuracy is : 0.5310168484224062
# At random state 2, the testing accuracy is : 0.5134202422634468
#
#
# At random state 3, the training accuracy is : 0.525294595786151
# At random state 3, the testing accuracy is : 0.5364997990196302
#
#
# At random state 4, the training accuracy is : 0.5311108651355041
# At random state 4, the testing accuracy is : 0.5135707366522664
#
#
# At random state 5, the training accuracy is : 0.5277471380432086
# At random state 5, the testing accuracy is : 0.5271433665925185
#
#
# At random state 6, the training accuracy is : 0.525999499594234
# At random state 6, the testing accuracy is : 0.5339504413782903
#
#
# At random state 7, the training accuracy is : 0.5236938144795575
# At random state 7, the testing accuracy is : 0.5431077720387001
#
#
# At random state 8, the training accuracy is : 0.5279521850936004
# At random state 8, the testing accuracy is : 0.5263539204114351
#
#
# At random state 9, the training accuracy is : 0.5298815803335004
# At random state 9, the testing accuracy is : 0.5185028680457873
#
#
# At random state 10, the training accuracy is : 0.52620774246615
# At random state 10, the testing accuracy is : 0.5331798327216527
#
#
# At random state 11, the training accuracy is : 0.5264158958442366
# At random state 11, the testing accuracy is : 0.5326715945433407
#
#
# At random state 12, the training accuracy is : 0.5295717233445185
# At random state 12, the testing accuracy is : 0.5200943586541836
#
#
# At random state 13, the training accuracy is : 0.5297120540550166
# At random state 13, the testing accuracy is : 0.5193245046587238
#
#
# At random state 14, the training accuracy is : 0.525077835797507
# At random state 14, the testing accuracy is : 0.537366251282617
#
#
# At random state 15, the training accuracy is : 0.5307927913481783
# At random state 15, the testing accuracy is : 0.5146481749477843
#
#
# At random state 16, the training accuracy is : 0.5257765427209247
# At random state 16, the testing accuracy is : 0.5347128362672932
#
#
# At random state 17, the training accuracy is : 0.5211538739936841
# At random state 17, the testing accuracy is : 0.5520869603197985
#
#
# At random state 18, the training accuracy is : 0.5267022646656367
# At random state 18, the testing accuracy is : 0.5312285961801115
#
#
# At random state 19, the training accuracy is : 0.5266539927093892
# At random state 19, the testing accuracy is : 0.5313902662833856
#
#
# At random state 20, the training accuracy is : 0.5240761314433798
# At random state 20, the testing accuracy is : 0.5408138935568199
#
#
# At random state 21, the training accuracy is : 0.5270657562522583
# At random state 21, the testing accuracy is : 0.5296313816668985
#
#
# At random state 22, the training accuracy is : 0.5263110717709628
# At random state 22, the testing accuracy is : 0.5327267327291494
#
#
# At random state 23, the training accuracy is : 0.5303367334446973
# At random state 23, the testing accuracy is : 0.5171399569289477
#
#
# At random state 24, the training accuracy is : 0.5283200205977618
# At random state 24, the testing accuracy is : 0.5246245374333094
#
#
# At random state 25, the training accuracy is : 0.5303679402012496
# At random state 25, the testing accuracy is : 0.5154451953576499
#
#
# At random state 26, the training accuracy is : 0.5331276347492139
# At random state 26, the testing accuracy is : 0.5056986171241966
#
#
# At random state 27, the training accuracy is : 0.5274102093509109
# At random state 27, the testing accuracy is : 0.52846116900034
#
#
# At random state 28, the training accuracy is : 0.5302300422424775
# At random state 28, the testing accuracy is : 0.5171460413754935
#
#
# At random state 29, the training accuracy is : 0.5297546663154793
# At random state 29, the testing accuracy is : 0.5186069574002373
#
#
# At random state 30, the training accuracy is : 0.5264536485528901
# At random state 30, the testing accuracy is : 0.5320903448834762
#
#
# At random state 31, the training accuracy is : 0.5253912569635429
# At random state 31, the testing accuracy is : 0.5363097442706598
#
#
# At random state 32, the training accuracy is : 0.5311137161113041
# At random state 32, the testing accuracy is : 0.5124843308555405
#
#
# At random state 33, the training accuracy is : 0.5231462715990268
# At random state 33, the testing accuracy is : 0.5445960449471496
#
#
# At random state 34, the training accuracy is : 0.5333634756493232
# At random state 34, the testing accuracy is : 0.5035634604857677
#
#
# At random state 35, the training accuracy is : 0.5303776200698492
# At random state 35, the testing accuracy is : 0.5158144181255246
#
#
# At random state 36, the training accuracy is : 0.5267541899371123
# At random state 36, the testing accuracy is : 0.5308732200343775
#
#
# At random state 37, the training accuracy is : 0.530271098667358
# At random state 37, the testing accuracy is : 0.5171527686488167
#
#
# At random state 38, the training accuracy is : 0.525635645638769
# At random state 38, the testing accuracy is : 0.5356129882117318
#
#
# At random state 39, the training accuracy is : 0.5298402077837163
# At random state 39, the testing accuracy is : 0.518769473257361
#
#
# At random state 40, the training accuracy is : 0.5287920307063563
# At random state 40, the testing accuracy is : 0.5226788798158095
#
#
# At random state 41, the training accuracy is : 0.5274031315465078
# At random state 41, the testing accuracy is : 0.5282196750578165
#
#
# At random state 42, the training accuracy is : 0.5299403982480149
# At random state 42, the testing accuracy is : 0.5182314687607266
#
#
# At random state 43, the training accuracy is : 0.5291364611242584
# At random state 43, the testing accuracy is : 0.5209716555380853
#
#
# At random state 44, the training accuracy is : 0.5300921376856619
# At random state 44, the testing accuracy is : 0.5162721779662861
#
#
# At random state 45, the training accuracy is : 0.5284185408255977
# At random state 45, the testing accuracy is : 0.524485016029949
#
#
# At random state 46, the training accuracy is : 0.5311592674387542
# At random state 46, the testing accuracy is : 0.5118908563793929
#
#
# At random state 47, the training accuracy is : 0.5315501374203908
# At random state 47, the testing accuracy is : 0.5120005733746564
#
#
# At random state 48, the training accuracy is : 0.528166633096737
# At random state 48, the testing accuracy is : 0.5253691914982364
#
#
# At random state 49, the training accuracy is : 0.5284825823862336
# At random state 49, the testing accuracy is : 0.5243134623620461
#
#
# At random state 50, the training accuracy is : 0.5255219910837277
# At random state 50, the testing accuracy is : 0.5348900544254463
#
#
# At random state 51, the training accuracy is : 0.5290911970320933
# At random state 51, the testing accuracy is : 0.5211653682406523
#
#
# At random state 52, the training accuracy is : 0.5290950152103824
# At random state 52, the testing accuracy is : 0.5212502248335865
#
#
# At random state 53, the training accuracy is : 0.5294392916436248
# At random state 53, the testing accuracy is : 0.5203488206934901
#
#
# At random state 54, the training accuracy is : 0.528750278431612
# At random state 54, the testing accuracy is : 0.5229352085946835
#
#
# At random state 55, the training accuracy is : 0.5329527215332536
# At random state 55, the testing accuracy is : 0.5053545179041928
#
#
# At random state 56, the training accuracy is : 0.5258405752696247
# At random state 56, the testing accuracy is : 0.5331151932559295
#
#
# At random state 57, the training accuracy is : 0.5273162015966659
# At random state 57, the testing accuracy is : 0.5285528360594893
#
#
# At random state 58, the training accuracy is : 0.529249915740413
# At random state 58, the testing accuracy is : 0.5214307491900905
#
#
# At random state 59, the training accuracy is : 0.5307298498263717
# At random state 59, the testing accuracy is : 0.5149549020139454
#
#
# At random state 60, the training accuracy is : 0.5304473694542358
# At random state 60, the testing accuracy is : 0.5162410814449969
#
#
# At random state 61, the training accuracy is : 0.5270978509330408
# At random state 61, the testing accuracy is : 0.5295617676326325
#
#
# At random state 62, the training accuracy is : 0.5251898302630069
# At random state 62, the testing accuracy is : 0.5372616059409208
#
#
# At random state 63, the training accuracy is : 0.5303269977904352
# At random state 63, the testing accuracy is : 0.5167433500654967
#
#
# At random state 64, the training accuracy is : 0.5276875466358326
# At random state 64, the testing accuracy is : 0.5273347769330194
#
#
# At random state 65, the training accuracy is : 0.5251260191455083
# At random state 65, the testing accuracy is : 0.5373057940171959
#
#
# At random state 66, the training accuracy is : 0.5264089188683685
# At random state 66, the testing accuracy is : 0.5324493194362704
#
#
# At random state 67, the training accuracy is : 0.5250104254108245
# At random state 67, the testing accuracy is : 0.5381206978297594
#
#
# At random state 68, the training accuracy is : 0.5271198352667655
# At random state 68, the testing accuracy is : 0.5289767179371958
#
#
# At random state 69, the training accuracy is : 0.5260096165270003
# At random state 69, the testing accuracy is : 0.5336943774413925
#
#
# At random state 70, the training accuracy is : 0.5303429741675914
# At random state 70, the testing accuracy is : 0.5169025112279643
#
#
# At random state 71, the training accuracy is : 0.5249642922229903
# At random state 71, the testing accuracy is : 0.5378380232618049
#
#
# At random state 72, the training accuracy is : 0.5298004866089322
# At random state 72, the testing accuracy is : 0.5194356040035876
#
#
# At random state 73, the training accuracy is : 0.5265510764228574
# At random state 73, the testing accuracy is : 0.5320530919607137
#
#
# At random state 74, the training accuracy is : 0.5306880572812267
# At random state 74, the testing accuracy is : 0.5152921914495239
#
#
# At random state 75, the training accuracy is : 0.5254442529554855
# At random state 75, the testing accuracy is : 0.5358521212726346
#
#
# At random state 76, the training accuracy is : 0.5270306998093646
# At random state 76, the testing accuracy is : 0.5298608047689572
#
#
# At random state 77, the training accuracy is : 0.5315741443145956
# At random state 77, the testing accuracy is : 0.5104079399614848
#
#
# At random state 78, the training accuracy is : 0.5253512364328701
# At random state 78, the testing accuracy is : 0.5361812018887611
#
#
# At random state 79, the training accuracy is : 0.525821128244833
# At random state 79, the testing accuracy is : 0.5343008786648428
#
#
# At random state 80, the training accuracy is : 0.525523227667421
# At random state 80, the testing accuracy is : 0.5364644618505173
#
#
# At random state 81, the training accuracy is : 0.524945437386819
# At random state 81, the testing accuracy is : 0.5382561699978339
#
#
# At random state 82, the training accuracy is : 0.529263213651122
# At random state 82, the testing accuracy is : 0.5207783091868102
#
#
# At random state 83, the training accuracy is : 0.5328648341196977
# At random state 83, the testing accuracy is : 0.5061424683525622
#
#
# At random state 84, the training accuracy is : 0.5302046262856424
# At random state 84, the testing accuracy is : 0.5164617143024763
#
#
# At random state 85, the training accuracy is : 0.5278193580112549
# At random state 85, the testing accuracy is : 0.5270363239159239
#
#
# At random state 86, the training accuracy is : 0.5298536170099023
# At random state 86, the testing accuracy is : 0.5182677448719832
#
#
# At random state 87, the training accuracy is : 0.5251550136130569
# At random state 87, the testing accuracy is : 0.5380069848295232
#
#
# At random state 88, the training accuracy is : 0.5294690218768352
# At random state 88, the testing accuracy is : 0.5194760255593411
#
#
# At random state 89, the training accuracy is : 0.5282008388282473
# At random state 89, the testing accuracy is : 0.5254454181414769
#
#
# At random state 90, the training accuracy is : 0.5325279942085952
# At random state 90, the testing accuracy is : 0.5087150056708283
#
#
# At random state 91, the training accuracy is : 0.53102763133909
# At random state 91, the testing accuracy is : 0.5137467668026692
#
#
# At random state 92, the training accuracy is : 0.525179113096602
# At random state 92, the testing accuracy is : 0.5369512543637582
#
#
# At random state 93, the training accuracy is : 0.5273604212009431
# At random state 93, the testing accuracy is : 0.528615941514319
#
#
# At random state 94, the training accuracy is : 0.5285938613317651
# At random state 94, the testing accuracy is : 0.5236814057156982
#
#
# At random state 95, the training accuracy is : 0.5275501733750494
# At random state 95, the testing accuracy is : 0.5277464541007049
#
#
# At random state 96, the training accuracy is : 0.5292123632729724
# At random state 96, the testing accuracy is : 0.5202805988924948
#
#
# At random state 97, the training accuracy is : 0.529570468629476
# At random state 97, the testing accuracy is : 0.5192658056360933
#
#
# At random state 98, the training accuracy is : 0.5284405723915772
# At random state 98, the testing accuracy is : 0.5242719402636964
#
#
# At random state 99, the training accuracy is : 0.5276842749183204
# At random state 99, the testing accuracy is : 0.5268775466781968

# %%
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size = 0.20, random_state = 80)
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
pred_test = lr.predict(x_test)

# %%
print("R2 Score Is :", r2_score(y_test, pred_test))
# Out:
# R2 Score Is : 0.5364644618505173

# %%
train_accuracy = r2_score(y_train, pred_train)
test_accuracy = r2_score(y_test, pred_test)

for j in range(2,16):
    cv_score = cross_val_score(lr, x, y, cv=j)
    cv_mean = cv_score.mean()
    print(f"At cross fold {j}, the C.V score is {cv_mean} and accuracy for training is {train_accuracy} and accuracy for testing is {test_accuracy}")
# Out:
# At cross fold 2, the C.V score is -3.598558748981432 and accuracy for training is -0.8628430442061108 and accuracy for testing is 0.832001180520549
# At cross fold 3, the C.V score is 0.17720075414669276 and accuracy for training is -0.8628430442061108 and accuracy for testing is 0.832001180520549
# At cross fold 4, the C.V score is 0.11827775469301899 and accuracy for training is -0.8628430442061108 and accuracy for testing is 0.832001180520549
# At cross fold 5, the C.V score is 0.19578684516066122 and accuracy for training is -0.8628430442061108 and accuracy for testing is 0.832001180520549
# At cross fold 6, the C.V score is 0.13236788637515967 and accuracy for training is -0.8628430442061108 and accuracy for testing is 0.832001180520549
# At cross fold 7, the C.V score is 0.16181535980012948 and accuracy for training is -0.8628430442061108 and accuracy for testing is 0.832001180520549
# At cross fold 8, the C.V score is 0.1346196065333567 and accuracy for training is -0.8628430442061108 and accuracy for testing is 0.832001180520549
# At cross fold 9, the C.V score is 0.1614454379432982 and accuracy for training is -0.8628430442061108 and accuracy for testing is 0.832001180520549
# At cross fold 10, the C.V score is 0.12493550226658068 and accuracy for training is -0.8628430442061108 and accuracy for testing is 0.832001180520549
# At cross fold 11, the C.V score is 0.1516614989959658 and accuracy for training is -0.8628430442061108 and accuracy for testing is 0.832001180520549
# At cross fold 12, the C.V score is 0.13093293986793278 and accuracy for training is -0.8628430442061108 and accuracy for testing is 0.832001180520549
# At cross fold 13, the C.V score is 0.13442289919882186 and accuracy for training is -0.8628430442061108 and accuracy for testing is 0.832001180520549
# At cross fold 14, the C.V score is 0.12178967478527039 and accuracy for training is -0.8628430442061108 and accuracy for testing is 0.832001180520549
# At cross fold 15, the C.V score is 0.1432048420035358 and accuracy for training is -0.8628430442061108 and accuracy for testing is 0.832001180520549

# %%
xgb = XGBRegressor (verbosity =0)

for i in range(0,100):
    x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size =0.30, random_state =i)
    xgb.fit(x_train, y_train)
    pred_train = xgb.predict(x_train)
    pred_test = xgb.predict(x_test)
    print(f"At random state {i}, the training accuracy is : {r2_score(y_train, pred_train)}" )
    print(f"At random state {i}, the testing accuracy is : {r2_score(y_test, pred_test)}" )
    print('\n')
# Out:
# At random state 0, the training accuracy is : 0.9361349305026379
# At random state 0, the testing accuracy is : 0.8290197550562738
#
#
# At random state 1, the training accuracy is : 0.9313350259232918
# At random state 1, the testing accuracy is : 0.8313881663236211
#
#
# At random state 2, the training accuracy is : 0.9351333232794679
# At random state 2, the testing accuracy is : 0.8204856984008426
#
#
# At random state 3, the training accuracy is : 0.9295917977784841
# At random state 3, the testing accuracy is : 0.816925625255875
#
#
# At random state 4, the training accuracy is : 0.932037554010686
# At random state 4, the testing accuracy is : 0.8199900183285574
#
#
# At random state 5, the training accuracy is : 0.9322215928286629
# At random state 5, the testing accuracy is : 0.8297004241362462
#
#
# At random state 6, the training accuracy is : 0.9329770076054072
# At random state 6, the testing accuracy is : 0.8299784646664942
#
#
# At random state 7, the training accuracy is : 0.9302293544832462
# At random state 7, the testing accuracy is : 0.831344802118736
#
#
# At random state 8, the training accuracy is : 0.9336541767190403
# At random state 8, the testing accuracy is : 0.8225875993906495
#
#
# At random state 9, the training accuracy is : 0.9341665433853944
# At random state 9, the testing accuracy is : 0.8139618014068185
#
#
# At random state 10, the training accuracy is : 0.9308493646940492
# At random state 10, the testing accuracy is : 0.8145466008939285
#
#
# At random state 11, the training accuracy is : 0.9340178469361468
# At random state 11, the testing accuracy is : 0.8308704850810232
#
#
# At random state 12, the training accuracy is : 0.9330129021965854
# At random state 12, the testing accuracy is : 0.8240468988394676
#
#
# At random state 13, the training accuracy is : 0.931350211081515
# At random state 13, the testing accuracy is : 0.8239809925313657
#
#
# At random state 14, the training accuracy is : 0.9327414398676102
# At random state 14, the testing accuracy is : 0.8270321468813706
#
#
# At random state 15, the training accuracy is : 0.9333571720535435
# At random state 15, the testing accuracy is : 0.8173812163103671
#
#
# At random state 16, the training accuracy is : 0.9329335644823233
# At random state 16, the testing accuracy is : 0.826250232417661
#
#
# At random state 17, the training accuracy is : 0.9308179171699329
# At random state 17, the testing accuracy is : 0.8237666460580254
#
#
# At random state 18, the training accuracy is : 0.929449853972406
# At random state 18, the testing accuracy is : 0.8335714837507722
#
#
# At random state 19, the training accuracy is : 0.9322794680694692
# At random state 19, the testing accuracy is : 0.8215493577479953
#
#
# At random state 20, the training accuracy is : 0.9330555066588556
# At random state 20, the testing accuracy is : 0.831168902793181
#
#
# At random state 21, the training accuracy is : 0.9334757950647362
# At random state 21, the testing accuracy is : 0.8264647585240611
#
#
# At random state 22, the training accuracy is : 0.9319976122096141
# At random state 22, the testing accuracy is : 0.8248904625823085
#
#
# At random state 23, the training accuracy is : 0.9319353326275656
# At random state 23, the testing accuracy is : 0.8283960368659661
#
#
# At random state 24, the training accuracy is : 0.9313787166923877
# At random state 24, the testing accuracy is : 0.8279977089629066
#
#
# At random state 25, the training accuracy is : 0.9359364322473182
# At random state 25, the testing accuracy is : 0.8276266043245982
#
#
# At random state 26, the training accuracy is : 0.9315148953840896
# At random state 26, the testing accuracy is : 0.8221896352239446
#
#
# At random state 27, the training accuracy is : 0.9327001246672877
# At random state 27, the testing accuracy is : 0.8212470961592924
#
#
# At random state 28, the training accuracy is : 0.9315181309961896
# At random state 28, the testing accuracy is : 0.8136340791769232
#
#
# At random state 29, the training accuracy is : 0.9331941218882278
# At random state 29, the testing accuracy is : 0.8211312800112853
#
#
# At random state 30, the training accuracy is : 0.9303436811288878
# At random state 30, the testing accuracy is : 0.8301407380403834
#
#
# At random state 31, the training accuracy is : 0.9316495808208501
# At random state 31, the testing accuracy is : 0.8384107741985147
#
#
# At random state 32, the training accuracy is : 0.9315244616434375
# At random state 32, the testing accuracy is : 0.8218451590706196
#
#
# At random state 33, the training accuracy is : 0.9300768865007061
# At random state 33, the testing accuracy is : 0.8277533491553951
#
#
# At random state 34, the training accuracy is : 0.9351655426229419
# At random state 34, the testing accuracy is : 0.8192753690488546
#
#
# At random state 35, the training accuracy is : 0.931048088723868
# At random state 35, the testing accuracy is : 0.8132473749019815
#
#
# At random state 36, the training accuracy is : 0.9337300449224588
# At random state 36, the testing accuracy is : 0.8256051412905191
#
#
# At random state 37, the training accuracy is : 0.9332082918188126
# At random state 37, the testing accuracy is : 0.816991547270745
#
#
# At random state 38, the training accuracy is : 0.9334571849748613
# At random state 38, the testing accuracy is : 0.8226733995203543
#
#
# At random state 39, the training accuracy is : 0.9335522141168076
# At random state 39, the testing accuracy is : 0.8314987906020757
#
#
# At random state 40, the training accuracy is : 0.9331576709166239
# At random state 40, the testing accuracy is : 0.8259029420481323
#
#
# At random state 41, the training accuracy is : 0.932799701904876
# At random state 41, the testing accuracy is : 0.8242693177968385
#
#
# At random state 42, the training accuracy is : 0.93041960524746
# At random state 42, the testing accuracy is : 0.8194392932285016
#
#
# At random state 43, the training accuracy is : 0.932435212708366
# At random state 43, the testing accuracy is : 0.8235880158744323
#
#
# At random state 44, the training accuracy is : 0.934011232881533
# At random state 44, the testing accuracy is : 0.821278433753596
#
#
# At random state 45, the training accuracy is : 0.9336887314110776
# At random state 45, the testing accuracy is : 0.8241261189404263
#
#
# At random state 46, the training accuracy is : 0.9330558462289866
# At random state 46, the testing accuracy is : 0.8263603240168365
#
#
# At random state 47, the training accuracy is : 0.9327865787876675
# At random state 47, the testing accuracy is : 0.8224867831061867
#
#
# At random state 48, the training accuracy is : 0.9332615594077129
# At random state 48, the testing accuracy is : 0.8270451233317877
#
#
# At random state 49, the training accuracy is : 0.9347308431888002
# At random state 49, the testing accuracy is : 0.8289366034640054
#
#
# At random state 50, the training accuracy is : 0.9355842752111552
# At random state 50, the testing accuracy is : 0.8273826303772445
#
#
# At random state 51, the training accuracy is : 0.930704515054266
# At random state 51, the testing accuracy is : 0.8303960303148026
#
#
# At random state 52, the training accuracy is : 0.9316943724427192
# At random state 52, the testing accuracy is : 0.8192860308381688
#
#
# At random state 53, the training accuracy is : 0.9367932611791222
# At random state 53, the testing accuracy is : 0.8336494186938513
#
#
# At random state 54, the training accuracy is : 0.9270999135822932
# At random state 54, the testing accuracy is : 0.8225458749197951
#
#
# At random state 55, the training accuracy is : 0.9313937032110537
# At random state 55, the testing accuracy is : 0.8127965870740445
#
#
# At random state 56, the training accuracy is : 0.9325526339309467
# At random state 56, the testing accuracy is : 0.8290850257734783
#
#
# At random state 57, the training accuracy is : 0.9313624624111283
# At random state 57, the testing accuracy is : 0.813299992855265
#
#
# At random state 58, the training accuracy is : 0.9301403689232586
# At random state 58, the testing accuracy is : 0.8222401913153681
#
#
# At random state 59, the training accuracy is : 0.9321379827993964
# At random state 59, the testing accuracy is : 0.8228533390918952
#
#
# At random state 60, the training accuracy is : 0.9306066065985733
# At random state 60, the testing accuracy is : 0.8166916477365948
#
#
# At random state 61, the training accuracy is : 0.9328424294568688
# At random state 61, the testing accuracy is : 0.8303616115377265
# At random state 62, the training accuracy is : 0.9322143432201642
# At random state 62, the testing accuracy is : 0.826052704418306
#
#
# At random state 63, the training accuracy is : 0.931611910637888
# At random state 63, the testing accuracy is : 0.8298295114005148
#
#
# At random state 64, the training accuracy is : 0.9331016828208982
# At random state 64, the testing accuracy is : 0.814435066266356
#
#
# At random state 65, the training accuracy is : 0.932044507212064
# At random state 65, the testing accuracy is : 0.8347092339869047
#
#
# At random state 66, the training accuracy is : 0.9327707170056799
# At random state 66, the testing accuracy is : 0.8251966852029065
#
#
# At random state 67, the training accuracy is : 0.9306921694924459
# At random state 67, the testing accuracy is : 0.8303429515321848
#
#
# At random state 68, the training accuracy is : 0.9329026084080927
# At random state 68, the testing accuracy is : 0.8251584605035112
#
#
# At random state 69, the training accuracy is : 0.9335829835494757
# At random state 69, the testing accuracy is : 0.8310134077154503
#
#
# At random state 70, the training accuracy is : 0.9323909020258594
# At random state 70, the testing accuracy is : 0.8175848251665891
#
#
# At random state 71, the training accuracy is : 0.9299393553279398
# At random state 71, the testing accuracy is : 0.8318224792966328
#
#
# At random state 72, the training accuracy is : 0.9294206862906019
# At random state 72, the testing accuracy is : 0.8279722708664331
#
#
# At random state 73, the training accuracy is : 0.9305344804004404
# At random state 73, the testing accuracy is : 0.8191059088054691
#
#
# At random state 74, the training accuracy is : 0.9324116270345495
# At random state 74, the testing accuracy is : 0.8107983358724165
#
#
# At random state 75, the training accuracy is : 0.9311533821331663
# At random state 75, the testing accuracy is : 0.8283695995909438
#
#
# At random state 76, the training accuracy is : 0.9332244939645102
# At random state 76, the testing accuracy is : 0.8217127164826097
#
#
# At random state 77, the training accuracy is : 0.9306752878408324
# At random state 77, the testing accuracy is : 0.820255949743572
#
#
# At random state 78, the training accuracy is : 0.9338049233973492
# At random state 78, the testing accuracy is : 0.8219605134507614
#
#
# At random state 79, the training accuracy is : 0.9345675143440341
# At random state 79, the testing accuracy is : 0.8309963888547648
#
#
# At random state 80, the training accuracy is : 0.9326778599835315
# At random state 80, the testing accuracy is : 0.8268908222172922
#
#
# At random state 81, the training accuracy is : 0.9331790558258896
# At random state 81, the testing accuracy is : 0.8283330810856298
#
#
# At random state 82, the training accuracy is : 0.9336353055498837
# At random state 82, the testing accuracy is : 0.8262532134417396
#
#
# At random state 83, the training accuracy is : 0.9331502273494737
# At random state 83, the testing accuracy is : 0.8230181998443729
#
#
# At random state 84, the training accuracy is : 0.9355219861146884
# At random state 84, the testing accuracy is : 0.8215899826514955
#
#
# At random state 85, the training accuracy is : 0.9311314676852999
# At random state 85, the testing accuracy is : 0.8187579893884781
#
#
# At random state 86, the training accuracy is : 0.9313768403137375
# At random state 86, the testing accuracy is : 0.8325861709610884
#
#
# At random state 87, the training accuracy is : 0.9354067507138806
# At random state 87, the testing accuracy is : 0.8290699756117044
#
#
# At random state 88, the training accuracy is : 0.9329311486888467
# At random state 88, the testing accuracy is : 0.8280986948519451
#
#
# At random state 89, the training accuracy is : 0.9314185846652537
# At random state 89, the testing accuracy is : 0.8207195613970544
#
#
# At random state 90, the training accuracy is : 0.9346433313701518
# At random state 90, the testing accuracy is : 0.8199589685909552
#
#
# At random state 91, the training accuracy is : 0.9350066943122806
# At random state 91, the testing accuracy is : 0.8164857275720212
#
#
# At random state 92, the training accuracy is : 0.9354041242007852
# At random state 92, the testing accuracy is : 0.8260662856856674
#
#
# At random state 93, the training accuracy is : 0.9333084991472682
# At random state 93, the testing accuracy is : 0.8198072295929395
#
#
# At random state 94, the training accuracy is : 0.932526534445766
# At random state 94, the testing accuracy is : 0.8285758022767818
#
#
# At random state 95, the training accuracy is : 0.9331395832761603
# At random state 95, the testing accuracy is : 0.8240507452594799
#
#
# At random state 96, the training accuracy is : 0.9357685091048142
# At random state 96, the testing accuracy is : 0.825521452151164
#
#
# At random state 97, the training accuracy is : 0.9315679850978378
# At random state 97, the testing accuracy is : 0.8262189828196695
#
#
# At random state 98, the training accuracy is : 0.9296999820338988
# At random state 98, the testing accuracy is : 0.8259852559071182
#
#
# At random state 99, the training accuracy is : 0.9308393998626991
# At random state 99, the testing accuracy is : 0.8247979769727226

# %%
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size = 0.30, random_state = 53)
xgb.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %%
pred_test = xgb.predict(x_test)

# %%
print("R2 Score Is :", r2_score(y_test, pred_test))
# Out:
# R2 Score Is : 0.8336494186938513

# %%
train_accuracy1 = r2_score(y_train, pred_train)
test_accuracy1 = r2_score(y_test, pred_test)

for i in range(2,16):
    cv_score = cross_val_score(xgb, x, y, cv=i)
    cv_mean = cv_score.mean()
    print(f"At cross fold {i}, the C.V score is {cv_mean} and accuracy for training is {train_accuracy1} and accuracy for testing is {test_accuracy1}")
# Out:
# At cross fold 2, the C.V score is -0.5059496297210783 and accuracy for training is -0.8906087609493658 and accuracy for testing is 0.8336494186938513
# At cross fold 3, the C.V score is 0.16471665216645948 and accuracy for training is -0.8906087609493658 and accuracy for testing is 0.8336494186938513
# At cross fold 4, the C.V score is 0.11421385550654944 and accuracy for training is -0.8906087609493658 and accuracy for testing is 0.8336494186938513
# At cross fold 5, the C.V score is 0.3304456052074243 and accuracy for training is -0.8906087609493658 and accuracy for testing is 0.8336494186938513
# At cross fold 6, the C.V score is 0.3273428998473485 and accuracy for training is -0.8906087609493658 and accuracy for testing is 0.8336494186938513
# At cross fold 7, the C.V score is 0.3873792078230252 and accuracy for training is -0.8906087609493658 and accuracy for testing is 0.8336494186938513
# At cross fold 8, the C.V score is 0.37678411354344965 and accuracy for training is -0.8906087609493658 and accuracy for testing is 0.8336494186938513
# At cross fold 9, the C.V score is 0.40250287243657656 and accuracy for training is -0.8906087609493658 and accuracy for testing is 0.8336494186938513
# At cross fold 10, the C.V score is 0.3657447385626363 and accuracy for training is -0.8906087609493658 and accuracy for testing is 0.8336494186938513
# At cross fold 11, the C.V score is 0.42698508362964327 and accuracy for training is -0.8906087609493658 and accuracy for testing is 0.8336494186938513
# At cross fold 12, the C.V score is 0.3572476483931966 and accuracy for training is -0.8906087609493658 and accuracy for testing is 0.8336494186938513
# At cross fold 13, the C.V score is 0.40300265997552115 and accuracy for training is -0.8906087609493658 and accuracy for testing is 0.8336494186938513
# At cross fold 14, the C.V score is 0.4031039377378625 and accuracy for training is -0.8906087609493658 and accuracy for testing is 0.8336494186938513
# At cross fold 15, the C.V score is 0.4050926040084821 and accuracy for training is -0.8906087609493658 and accuracy for testing is 0.8336494186938513
